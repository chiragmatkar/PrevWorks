# %%
import pandas as pd

# %%
data = pd.read_csv("./data/processed_with_const_op.csv", index_col=[0])
data.head()
# Out:
#        age sex   nature_of_inj part_of_body         src_of_injury  \
# 31672   30   M        Puncture   FOOT/ANKLE         BODILY MOTION
# 31673   34   M        Fracture   FOOT/ANKLE                 OTHER
# 31674   40   M  Electric Shock      HAND(S)                 OTHER
# 31870   20   M        Asphyxia   OTHBODYSYS  BUILDINGS/STRUCTURES
# 31921   31   M  Electric Shock      HAND(S)   ELEC APPARAT/WIRING
#
#                  event_type    evn_factor                      hum_factor  \
# 31672                 OTHER         OTHER     MISJUDGMENT, HAZ. SITUATION
# 31673  FALL(FROM ELEVATION)         OTHER  EQUIP. INAPPROPR FOR OPERATION
# 31674                 SHOCK         OTHER     MISJUDGMENT, HAZ. SITUATION
# 31870                 OTHER         OTHER                           OTHER
# 31921                 SHOCK  ILLUMINATION     MISJUDGMENT, HAZ. SITUATION
#
#                                                 occ_code        degree_of_inj  \
# 31672                                            Roofers  Hospitalized injury
# 31673                                         Carpenters  Hospitalized injury
# 31674  Supervisors; electricians & power transm. inst...  Hospitalized injury
# 31870                            Occupation not reported             Fatality
# 31921                                       Electricians             Fatality
#
#                      task_assigned  \
# 31672      Task regularly assigned
# 31673      Task regularly assigned
# 31674      Task regularly assigned
# 31870      Task regularly assigned
# 31921  Task not regularly assigned
#
#                                           const_op  \
# 31672                                      Roofing
# 31673       Steel Erection Of Solid Web-Connecting
# 31674        Installing equipment (HVAC and other)
# 31870    Other Activities-Post Decking Detail Work
# 31921  Interior plumbing, ducting, electrical work
#
#                                     const_op_cause
# 31672                                      Roofing
# 31673       Steel Erection Of Solid Web-Connecting
# 31674        Installing equipment (HVAC and other)
# 31870    Other Activities-Post Decking Detail Work
# 31921  Interior plumbing, ducting, electrical work

# %% [markdown]
# ## Correcting for Unhealthy user bias

# %% [markdown]
# ## Multi-class classification task

# %%
# degree_of_injury ~ age, sex, const_op, task_assigned, occ_code
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
X, y = data[["age", "sex", "const_op", "task_assigned", "occ_code"]], data["degree_of_inj"]
X
# Out:
#         age sex                                     const_op  \
# 31672    30   M                                      Roofing
# 31673    34   M       Steel Erection Of Solid Web-Connecting
# 31674    40   M        Installing equipment (HVAC and other)
# 31870    20   M    Other Activities-Post Decking Detail Work
# 31921    31   M  Interior plumbing, ducting, electrical work
# ...     ...  ..                                          ...
# 203453   40   M                   Backfilling and compacting
# 203454   26   M                             Exterior masonry
# 203456   38   M   Installing interior walls, ceilings, doors
# 203470   39   M       Installing plumbing, lighting fixtures
# 203471   25   M        Installing equipment (HVAC and other)
#
#                       task_assigned  \
# 31672       Task regularly assigned
# 31673       Task regularly assigned
# 31674       Task regularly assigned
# 31870       Task regularly assigned
# 31921   Task not regularly assigned
# ...                             ...
# 203453      Task regularly assigned
# 203454      Task regularly assigned
# 203456      Task regularly assigned
# 203470      Task regularly assigned
# 203471      Task regularly assigned
#
#                                                  occ_code
# 31672                                             Roofers
# 31673                                          Carpenters
# 31674   Supervisors; electricians & power transm. inst...
# 31870                             Occupation not reported
# 31921                                        Electricians
# ...                                                   ...
# 203453  Paving, surfacing and tamping equipment operators
# 203454                    Concrete and terrazzo finishers
# 203456                            Occupation not reported
# 203470                                       Electricians
# 203471             Plumbers, pipefitters and steamfitters
#
# [15441 rows x 5 columns]

# %%
# one-hot
X = pd.get_dummies(X, drop_first=True)
X
# Out:
#         age  sex_M  const_op_Bituminous concrete placement  \
# 31672    30      1                                       0
# 31673    34      1                                       0
# 31674    40      1                                       0
# 31870    20      1                                       0
# 31921    31      1                                       0
# ...     ...    ...                                     ...
# 203453   40      1                                       0
# 203454   26      1                                       0
# 203456   38      1                                       0
# 203470   39      1                                       0
# 203471   25      1                                       0
#
#         const_op_Construction of playing fields, tennis courts  \
# 31672                                                   0
# 31673                                                   0
# 31674                                                   0
# 31870                                                   0
# 31921                                                   0
# ...                                                   ...
# 203453                                                  0
# 203454                                                  0
# 203456                                                  0
# 203470                                                  0
# 203471                                                  0
#
#         const_op_Cutting concrete pavement  const_op_Demolition  \
# 31672                                    0                    0
# 31673                                    0                    0
# 31674                                    0                    0
# 31870                                    0                    0
# 31921                                    0                    0
# ...                                    ...                  ...
# 203453                                   0                    0
# 203454                                   0                    0
# 203456                                   0                    0
# 203470                                   0                    0
# 203471                                   0                    0
#
#         const_op_Dredging  const_op_Elevator, escalator installation  \
# 31672                   0                                          0
# 31673                   0                                          0
# 31674                   0                                          0
# 31870                   0                                          0
# 31921                   0                                          0
# ...                   ...                                        ...
# 203453                  0                                          0
# 203454                  0                                          0
# 203456                  0                                          0
# 203470                  0                                          0
# 203471                  0                                          0
#
#         const_op_Emplacing reinforcing steel  \
# 31672                                      0
# 31673                                      0
# 31674                                      0
# 31870                                      0
# 31921                                      0
# ...                                      ...
# 203453                                     0
# 203454                                     0
# 203456                                     0
# 203470                                     0
# 203471                                     0
#
#         const_op_Erecting structural steel  ...  \
# 31672                                    0  ...
# 31673                                    0  ...
# 31674                                    0  ...
# 31870                                    0  ...
# 31921                                    0  ...
# ...                                    ...  ...
# 203453                                   0  ...
# 203454                                   0  ...
# 203456                                   0  ...
# 203470                                   0  ...
# 203471                                   0  ...
#
#         occ_code_Tile setters, hard and soft  \
# 31672                                      0
# 31673                                      0
# 31674                                      0
# 31870                                      0
# 31921                                      0
# ...                                      ...
# 203453                                     0
# 203454                                     0
# 203456                                     0
# 203470                                     0
# 203471                                     0
#
#         occ_code_Timber cutting and logging occupations  \
# 31672                                                 0
# 31673                                                 0
# 31674                                                 0
# 31870                                                 0
# 31921                                                 0
# ...                                                 ...
# 203453                                                0
# 203454                                                0
# 203456                                                0
# 203470                                                0
# 203471                                                0
#
#         occ_code_Trade and industrial teachers  occ_code_Truck drivers, heavy  \
# 31672                                        0                              0
# 31673                                        0                              0
# 31674                                        0                              0
# 31870                                        0                              0
# 31921                                        0                              0
# ...                                        ...                            ...
# 203453                                       0                              0
# 203454                                       0                              0
# 203456                                       0                              0
# 203470                                       0                              0
# 203471                                       0                              0
#
#         occ_code_Truck drivers, light  occ_code_Typists  \
# 31672                               0                 0
# 31673                               0                 0
# 31674                               0                 0
# 31870                               0                 0
# 31921                               0                 0
# ...                               ...               ...
# 203453                              0                 0
# 203454                              0                 0
# 203456                              0                 0
# 203470                              0                 0
# 203471                              0                 0
#
#         occ_code_Urban planners  \
# 31672                         0
# 31673                         0
# 31674                         0
# 31870                         0
# 31921                         0
# ...                         ...
# 203453                        0
# 203454                        0
# 203456                        0
# 203470                        0
# 203471                        0
#
#         occ_code_Vehicle washers and equipment cleaners  \
# 31672                                                 0
# 31673                                                 0
# 31674                                                 0
# 31870                                                 0
# 31921                                                 0
# ...                                                 ...
# 203453                                                0
# 203454                                                0
# 203456                                                0
# 203470                                                0
# 203471                                                0
#
#         occ_code_Weighers, measurers and checkers  \
# 31672                                           0
# 31673                                           0
# 31674                                           0
# 31870                                           0
# 31921                                           0
# ...                                           ...
# 203453                                          0
# 203454                                          0
# 203456                                          0
# 203470                                          0
# 203471                                          0
#
#         occ_code_Welders and cutters
# 31672                              0
# 31673                              0
# 31674                              0
# 31870                              0
# 31921                              0
# ...                              ...
# 203453                             0
# 203454                             0
# 203456                             0
# 203470                             0
# 203471                             0
#
# [15441 rows x 239 columns]

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# Model fit and predict
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
print(classification_report(y_true=y_test, y_pred=clf.predict(X_test)))
# Out:
#                          precision    recall  f1-score   support
#
#                Fatality       0.53      0.51      0.52      2124
#     Hospitalized injury       0.56      0.61      0.59      2509
# Non Hospitalized injury       0.17      0.12      0.14       463
#
#                accuracy                           0.53      5096
#               macro avg       0.42      0.41      0.42      5096
#            weighted avg       0.51      0.53      0.52      5096

# %%
from imblearn.ensemble import BalancedRandomForestClassifier
# Model fit and predict
balanced_clf = BalancedRandomForestClassifier()
balanced_clf.fit(X_train, y_train)
print(classification_report(y_true=y_test, y_pred=balanced_clf.predict(X_test)))
# Out:
#                          precision    recall  f1-score   support
#
#                Fatality       0.57      0.50      0.53      2124
#     Hospitalized injury       0.59      0.38      0.46      2509
# Non Hospitalized injury       0.13      0.45      0.20       463
#
#                accuracy                           0.43      5096
#               macro avg       0.43      0.44      0.40      5096
#            weighted avg       0.54      0.43      0.47      5096

# %%
# Fatal vs Non-fatal
y_fatal_train, y_fatal_test = y_train.replace("Hospitalized injury", "Non-fatal").replace("Non Hospitalized injury", "Non-fatal"), y_test.replace("Hospitalized injury", "Non-fatal").replace("Non Hospitalized injury", "Non-fatal")

# %%
# Model fit and predict
fatal_clf = RandomForestClassifier()
fatal_clf.fit(X_train, y_fatal_train)
print(classification_report(y_true=y_fatal_test, y_pred=fatal_clf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#     Fatality       0.54      0.48      0.51      2124
#    Non-fatal       0.66      0.70      0.68      2972
#
#     accuracy                           0.61      5096
#    macro avg       0.60      0.59      0.59      5096
# weighted avg       0.61      0.61      0.61      5096

# %%
# Model fit and predict
balanced_fatal_clf = BalancedRandomForestClassifier()
balanced_fatal_clf.fit(X_train, y_fatal_train)
print(classification_report(y_true=y_fatal_test, y_pred=balanced_fatal_clf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#     Fatality       0.52      0.59      0.55      2124
#    Non-fatal       0.68      0.61      0.64      2972
#
#     accuracy                           0.60      5096
#    macro avg       0.60      0.60      0.60      5096
# weighted avg       0.61      0.60      0.60      5096

# %%
# Severe vs Non-severe
y_severe_train, y_severe_test = y_train.replace("Hospitalized injury", "Severe").replace("Fatality", "Severe"), y_test.replace("Hospitalized injury", "Severe").replace("Fatality", "Severe")

# %%
# Model fit and predict
severe_clf = RandomForestClassifier()
severe_clf.fit(X_train, y_severe_train)
print(classification_report(y_true=y_severe_test, y_pred=severe_clf.predict(X_test)))
# Out:
#                          precision    recall  f1-score   support
#
# Non Hospitalized injury       0.20      0.10      0.13       463
#                  Severe       0.91      0.96      0.94      4633
#
#                accuracy                           0.88      5096
#               macro avg       0.56      0.53      0.53      5096
#            weighted avg       0.85      0.88      0.86      5096

# %%
# Model fit and predict
balanced_severe_clf = BalancedRandomForestClassifier()
balanced_severe_clf.fit(X_train, y_severe_train)
print(classification_report(y_true=y_severe_test, y_pred=balanced_severe_clf.predict(X_test)))
# Out:
#                          precision    recall  f1-score   support
#
# Non Hospitalized injury       0.12      0.60      0.20       463
#                  Severe       0.93      0.57      0.70      4633
#
#                accuracy                           0.57      5096
#               macro avg       0.53      0.58      0.45      5096
#            weighted avg       0.86      0.57      0.66      5096
